# %% [markdown]
# # 03 — Model training
#
# Prefer `python scripts/train.py` for full runs. This notebook sketches a tiny synthetic fit.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))

from data.synthetic import generate_dataset
from preprocessing.feature_engineer import zscore_batch
from training.train import fit
from src.config import CHECKPOINTS_DIR

X, y = generate_dataset(n_per_class=40)
X = zscore_batch(X)
fit(X, y, epochs=3, augment_copies=0, out_path=CHECKPOINTS_DIR / 'notebook_demo.pt')
