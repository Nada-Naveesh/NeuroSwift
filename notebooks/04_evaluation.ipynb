# %% [markdown]
# # 04 — Evaluation
#
# After training, run `python scripts/evaluate.py` and inspect `reports/evaluation.json` plus `reports/figures/confusion_matrix.png`.

# %%
from pathlib import Path
p = Path('..') / 'reports' / 'evaluation.json'
print('evaluation.json exists:' , p.exists())
if p.exists():
    print(p.read_text()[:1000])
