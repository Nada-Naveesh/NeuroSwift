# %% [markdown]
# # 02 — Preprocessing
#
# Bandpass, trial shape, and z-score on a synthetic window. For EDF files use `scripts/preprocess.py`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))

from data.synthetic import generate_trial
from preprocessing.feature_engineer import ensure_trial_shape, zscore_trial
import numpy as np

raw_trial = generate_trial(0, np.random.default_rng(1))
prep = zscore_trial(ensure_trial_shape(raw_trial))
print(prep.shape, prep.mean(), prep.std())
